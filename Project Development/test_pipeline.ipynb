# %%
#Import necessary packages
import requests
import pickle
import pandas as pd
import numpy as np
from pymongo import MongoClient
from datetime import date
import time

#Bring in pickled objects
list_of_topics = pickle.load(open('list_of_topics','rb'))

#Open MongoDB connection
client = MongoClient()

#Create database/start connection to databse
db = client.news
articles = db.news

# %%
#Create function for API query initial database
def query_news(topic):
    url = "https://free-news.p.rapidapi.com/v1/search"
    querystring = {'q': topic,'lang':'en', 'page_size':'100'}
    headers = {
        'x-rapidapi-key': '780fcaeeb3mshf9210d76d977dc2p1702dbjsn0f8d212f07b3',
        'x-rapidapi-host': 'free-news.p.rapidapi.com'
        }
    response = requests.request("GET", url, headers=headers, params=querystring)
    return response.json()

#Create test workflow to ensure database and functions are working properly
#Create test collection
#test_collection = db.news

#Query API
test_query = query_news('flooding')

#Pull out articles specifically
query_to_insert = list(test_query['articles'])

#Insert articles
db.test_collection.insert_many(query_to_insert)

#Test to ensure articles are contained in database
list(db.test_collection.find({}, {'_id':0, 'title': 1}))

#Pull articles from API
for topic in list_of_topics:
    try:
        working_query = query_news(topic)
        working_query = list(working_query['articles'])
        db.articles.insert_many(working_query, ordered=False)
    except:
        print('No articles found for the following topic:', topic)
    print(db.articles.count(), 'articles added so far')
    time.sleep(1)

# %%
# Out:
# ["MeToo gave women the power to say 'no'",
#  "The #MeToo Movement Gave Women the Power to Say ‘No'",
#  'Sexual harassment',
#  "Gloria Allred Isn't Worried About What Bill Cosby's Release Means for MeToo",
#  'Lecturer wins damages from #MeToo blog that falsely accused him of rape',
#  "Casanova and His Female Counterparts, in Benoît Jacquot's Latest",
#  'Case registered against Bollywood producer Bhushan Kumar on allegations of rape',
#  "Harnessing Sri Lanka's #metoo Moment into a Movement",
#  "Cannes falls for 'The Worst Person in the World'",
#  "Cannes falls for 'The Worst Person in the World'",
#  "Cannes falls for 'The Worst Person in the World'",
#  "Cannes falls for 'The Worst Person in the World'",
#  "Cannes falls for 'The Worst Person in the World'",
#  "Cannes falls for 'The Worst Person in the World'",
#  'Partisans are more likely to believe that members of the other party are guilty of sexual misconduct than members of their own party. There is an exception to this: Individuals who support the #MeToo',
#  "High-Profile Harvey Weinstein Movie 'She Said' Lands Thanksgiving 2022 Release in Theaters",
#  'Marvel + #MeToo + political propaganda = Black Widow, a middling, formulaic Disney money grab',
#  "Cannes falls for 'The Worst Person in the World'",
#  "Cannes falls for 'The Worst Person in the World'",
#  'Sexual assault survivors\xa0are forced to seek justice their way',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  '#MeToo in Egypt: Abused women speak out',
#  "Cannes falls for ‘The Worst Person in the World'",
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  "Cannes Falls For 'The Worst Person In The World'",
#  "‘Mad Men, Furious Women': Viral blog post sparks talk of advertising industry's #MeToo moment",
#  "‘Spitting' scientist, Professor Stuart Munro, faces calls to resign",
#  "‘Abusive' scientist, Professor Stuart Munro, faces calls to resign",
#  "'Catch and Kill: The Podcast Tapes' Is Six Episodes of What We Already Knew",
#  "Scientist rebuked over ‘spitting' incident",
#  "'Black Box' shines a light on shadowy realities of sexual assault in Japan",
#  "‘There's a lot more to it': docuseries goes behind the 2017 Weinstein exposé",
#  'African women – information, recherche et analyse – La Conversation',
#  'Adding social issues to the corporate balance sheet',
#  "Sex tape furore sparks Cameroon's #MeToo moment",
#  'African women – News, Research and Analysis – The Conversation – page 1',
#  'African women – information, recherche et analyse – The Conversation France, page 1',
#  "Sex tape furore sparks Cameroon's #MeToo moment",
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'African women – Berita, Riset, dan Analisis – The Conversation – laman 1',
#  "Sex tape furore sparks Cameroon's #MeToo moment",
#  'Ndtv News Desk With Inputs From Agencies : Latest News, Photos, Videos on Ndtv News Desk With Inputs From Agencies',
#  "Disgraced comedian Louis C.K. is playing Madison's Comedy on State, selling out shows and drawing backlash",
#  "Sex tape furore sparks Cameroon's #MeToo moment",
#  'The Global #MeToo Movement, With Rachel B. Vogelstein and Meighan Stone',
#  'Sexual violence – Berita, Riset, dan Analisis – The Conversation – laman 1',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'Sexual violence – News, Research and Analysis – The Conversation – page 1',
#  'Sexual violence – information, recherche et analyse – The Conversation France, page 1',
#  "The Pandemic Hasn't Stopped the Rise of the Women's Movement",
#  'Former band frontman Daniel Hanson jailed for 28 years for raping 14 women and girls',
#  'Sexual violence – information, recherche et analyse – La Conversation',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'Female role models News, Research and Analysis',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  'New & Noteworthy, From Finding Joy to Offbeat Sports Stories',
#  "Carey Mulligan's Weinstein Investigation Film 'She Said' Gets 2022 Release Date",
#  "Advertising sector has #MeToo moment as blog sparks women's anger",
#  'For top #MeToo legal duo, a pandemic year brings no pause',
#  "Weinstein Investigation Movie 'She Said' With Carey Mulligan and Zoe Kazan to Debut in 2022",
#  "Weinstein Investigation Movie ‘She Said' With Carey Mulligan and Zoe Kazan to Debut in 2022",
#  "Harvey Weinstein investigation movie 'She Said' gets Nov 2022 release date",
#  "FIR against T-Series managing director Bhushan Kumar for ‘raping' woman",
#  "Five Bedrooms actor Kat Stewart on COVID's impact on the performing arts, and the Australian entertainment sector post-#MeToo",
#  'For #MeToo attorneys representing survivors, pandemic year is the biggest they have had-Living News , Firstpost',
#  "Anthony Bourdain's ‘addiction' to Asia Argento overtook last year of his life, new documentary says",
#  "Anthony Bourdain's ‘addiction' to Asia Argento overtook last year of his life, new documentary shows",
#  "Anthony Bourdain's ‘addiction' to Asia Argento overtook last year of his life, new documentary shows",
#  'Biden\'s "secret war" with Kamala in this week\'s dubious tabloids',
#  "Weinstein Investigation Movie ‘She Said' With Carey Mulligan and Zoe Kazan to Debut in 2022",
#  "‘RatMagnet's' New Collaboration Brew Aims To Make The Beer Industry's #MeToo Moment Last",
#  "'I woke up and puked': Cannes star Renate Reinsve on new-found fame",
#  "'I woke up and puked': Cannes star Renate Reinsve on new-found fame",
#  "‘I woke up and puked': Cannes star Renate Reinsve on new-found fame",
#  "'I woke up and puked': Cannes star Renate Reinsve on new-found fame",
#  "'Makeup for men is no big deal': a former male model on why it's time to take up the bronzer",
#  "‘She Said' Gets Release Date; Pic Based On Book About Harvey Weinstein Case Stars Carey Mulligan & Zoe Kazan",
#  'Global #MeToo Movement Has the Potential to Revolutionize Gender Roles, New Book Reveals',
#  "Ford and GM replace 'chairman' title with gender-neutral 'chair'",
#  '8 Fascinating Talks About Women In Film To Watch This Weekend For Under A Fiver',
#  "Three New Yorker stories to read when you're missing Anthony Bourdain",
#  'Rise in workers requesting sick notes ahead of return to offices',
#  'New Documentary Seeks to Understand Anthony Bourdain and His Death',
#  "Ford and GM Replace ‘Chairman' Title With Gender-Neutral ‘Chair'",
#  'Perry & Young law firm resolves sexual assault case for insurance limits',
#  'Moon Trees: The Story of Seeds That Went to Outer Space',
#  "Ambassador Pyatt's Remarks at Sister Cities International Mayors Leadership Council",
#  'Ohio GOP chair, former sr. advisor to former President Trump, to keynote annual Gallia GOP corn roast',
#  'We found nearly $400 million rotting in a forgotten taxpayer-funded government account',
#  'FACT CHECK: Biden Falsely Claims Supreme Court Heard 2020 Election Challenges',
#  "California gubernatorial candidate Caitlyn Jenner, who is polling at 6%, says 'I guarantee you that I am in the lead'",
#  'Chido Sanyatwe',
#  'Caitlyn Jenner pays film crews to shoot political campaign, may sell footage as reality TV',
#  'US House of Representatives – News, Research and Analysis – The Conversation – page 1',
#  'US House of Representatives – Berita, Riset, dan Analisis – The Conversation – laman 1',
#  'US House of Representatives – information, recherche et analyse – The Conversation France, page 1',
#  'US House of Representatives – information, recherche et analyse – La Conversation',
#  "California gubernatorial candidate Caitlyn Jenner, who is polling at 6%, says 'I guarantee you that I am in the lead'",
#  "Amanda Seyfried Shares Old Photo From 'Mean Girls' Days — And It's Not Even Oct. 3",
#  "California gubernatorial candidate Caitlyn Jenner, who is polling at 6%, says 'I guarantee you that I am in the lead'",
#  'Winston partner withdraws as lawyer for pro-Trump election challenger',
#  "Amanda Seyfried Shares Old Photo From 'Mean Girls' Days — And It's Not Even Oct. 3",
#  "Trump's Revenge Begins in Georgia",
#  'Why a 2020 Election Hero Is Probably Doomed in Georgia',
#  "Which Party Is Sane Enough to Win Philly's Suburbs?",
#  "Ramp it up: It's time for Biden and all of us to mobilize like MLK to save voting rights.",
#  'Judge grills lawyers on thin election fraud claims at Michigan hearing on possible sanctions',
#  'Bolsonaro Wages Trumpian Campaign to Sow Doubts About Voting',
#  'Ad War Erupts in West Virginia as Both Sides Try to Pressure Moderate Democrat Manchin',
#  "Tucker Carlson called Trump 'the single most repulsive person on the planet' and a 'wacko' in 1999",
#  "There's a Dirty Tricks Campaign Underway in Peru to Deny the Left's Presidential Victory",
#  "Colorado's top elections official calls out lies, 'blatant abuse,' and voter suppression being used by GOP officials 'a tool to steal future elections'",
#  'Judge grills lawyers on thin election fraud claims at Michigan hearing on possible sanctions :: WRAL.com',
#  '2020 election: Judge grills lawyers on thin fraud claims at Michigan hearing on possible sanctions',
#  "Ramp it up: It's time for Biden and all of us to mobilize like MLK to save voting rights.",
#  "Peru's Democracy Is at a Breaking Point",
#  "Ramp it up: It's time for Biden and all of us to mobilize like MLK to save voting rights.",
#  "There's a Dirty Tricks Campaign Underway in Peru to Deny the Left's Presidential Victory",
#  'Jair Bolsonaro wages Trump-like campaign to sow doubt over voting in Brazil',
#  'Lisa Murkowski Has Angered Trump With Her Insistence on Staying (Relatively) Sane',
#  'Lisa Murkowski Primary Challenger Kelly Tshibaka Earns Trump Endorsement',
#  "Mitch McConnell Laughs Off Trump's 'Old Crow' Insult: 'It's Quite an Honor'",
#  'Opinion: Compulsory voting waters the seed of Democracy',
#  "Colorado's top elections official calls out lies, 'blatant abuse,' and voter suppression being used by GOP officials 'a tool to steal future elections'",
#  'Bolsonaro wages Trumpian campaign to sow doubts about voting',
#  "Tucker Carlson called Trump 'the single most repulsive person on the planet' and a 'wacko' in 1999",
#  "Tucker Carlson called Trump 'the single most repulsive person on the planet' and a 'wacko' in 1999",
#  'Analysis: Louisiana to have new approach for voting machines',
#  'Analysis: Louisiana to have new approach for voting machines',
#  'Analysis: Louisiana to have new approach for voting machines',
#  'Analysis: Louisiana to have new approach for voting machines',
#  'Analysis: Louisiana to have new approach for voting machines',
#  "Protesters worldwide waving US flags as ‘symbol of freedom,' I have bad news for you – it now stands for Snitch Nation",
#  'Analysis: Louisiana to have new approach for voting machines',
#  'The crisis in Cuba creates a raft of problems for President Biden',
#  'Oil and Gas Heir Backs Pro-Israel Group Attacking Nina Turner',
#  'Why Florida has allowed Cuba protesters to shut down highway after making it a felony for Black Lives Matter',
#  'Kristi Noem still brags about defying public health advice — but an expert just showed why it was a disaster',
#  'Top generals feared Trump coup attempt after election loss, according to new\xa0book',
#  "Trump says he has no financial interests in Russia. Here's a run-down of the decades his businesses have spent trying make his mark there.",
#  "Trump says he has no financial interests in Russia. Here's a run-down of the decades his businesses have spent trying make his mark there.",
#  'Hundreds greet Aristide on return to troubled Haiti',
#  'What you need to know about hotly debated US voting laws',
#  "Democrats' midterm exposure to blue state high unemployment",
#  "Dems Helped Give Us Trump—They Shouldn't Repeat That Mistake",
#  'How Democracy Could Die in 2024, and How to Save It',
#  'The Biggest Threat to Democracy Is the GOP Stealing the Next Election',
#  'Gambia Govt Sentence Ex Dictator, Yahya Jammeh To Death For Murder',
#  'Presidential pardons in Sri Lanka; Some are more equal than others',
#  'Women must be included in conflict mediation in Somalia',
#  'Women must be included in conflict mediation in Somalia',
#  'Florida allows Cuba protesters to shut down highway despite making it felony for Black Lives Matter',
#  "Dems Helped Give Us Trump—They Shouldn't Repeat That Mistake",
#  "‘We Interrupt This Broadcast: Before It Was History, It Was News' – New Audio Docuseries Debuts July 20, 2021",
#  'Newsom vs. Davis: A Review of Two Very Different Recalls',
#  'The D.C. Doldrums',
#  "Why Is a Florida-Based Pastor Under Arrest for the Assassination of Haiti's President?",
#  'Celebrate Mandela Day with these inspirational books on the life of Nelson Mandela',
#  "Why Is a Florida-Based Pastor Under Arrest for the Assassination of Haiti's President?",
#  '10 things you need to know today: July 13, 2021',
#  'Want to bring bipartisanship back? End the filibuster now',
#  'Is Israel preparing for the inevitable civil war in the West Bank?',
#  'Democrats need to play hardball to force the GOP to moderate',
#  "Haiti: Investigate President's Killing",
#  'Nigeria: The Mistake of 1914 (III)',
#  'Edwin Edwards, the legendary and controversial four-term governor of Louisiana, dies at age 93',
#  'Edwin Edwards, the legendary and controversial four term governor of Louisiana, dies at age 93',
#  'Honduras must stop criminalising defence of indigenous rights, say UN experts',
#  'An age of alienation: why we must end the dangerous decline in community life',
#  'Why Are We Fueling Our Own Extinction?',
#  'Ten Stocks You Can Buy For About 10 Times Earnings',
#  "Here's what happens when Texas Democrats flee the state to derail legislation",
#  "Here's what happens when Texas lawmakers flee the state to derail legislation",
#  "The person to ‘weaken' America: what the Kremlin papers said about Trump",
#  'Biden knows Afghanistan withdrawal is the right thing — despite political risks',
#  'Biden knows Afghanistan withdrawal is the right thing — despite political risks',
#  "US Sponsored Coup d'État: The Destabilization of Haiti",
#  "US Sponsored Coup d'État: The Destabilization of Haiti",
#  'Overnight News Digest: Climate and democracy in crisis',
#  "What's the Deal With Curtis Sliwa, the Red Beret'd, Cat-Loving Vigilante Running for NYC Mayor?",
#  '15 Woke Hollywood Celebrities Who Hobnobbed, Vacationed, Promoted Movies in Communist Cuba',
#  "Joe Biden's precipitous retreat from Afghanistan abandons both the Afghan people and America's credibility as an ally",
#  'Redistricting Will Always Be Contentious. Ask Arizona.',
#  'Mystery grows around suspect in Haiti president killing',
#  'Crime and punishment',
#  'Crime and punishment',
#  'Thousands marched in France and Greece after new vaccination rules were issued.',
#  'U.N. Haiti envoy says Joseph to remain prime minister for now',
#  'Texas Man Charged After Allegedly Voting While on Probation',
#  'Texas man arrested on illegal voting charges after casting ballot on parole',
#  'Texas man hailed as national hero arrested for illegal voting',
#  "Opinion: Haiti needs the world's help",
#  'Veteran politician becomes Nepal prime minister for 5th time',
#  'U.S. Military, Which Jill Biden Will Lecture About Race, Is More Diverse than Federal Government',
#  'Veteran politician becomes Nepal prime minister for 5th time',
#  'Veteran politician becomes Nepal prime minister for 5th time',
#  'Veteran politician becomes Nepal prime minister for 5th time',
#  'Veteran politician becomes Nepal prime minister for 5th time',
#  'U.S. Military, Which Jill Biden Will Lecture About Race, Is More Diverse than Federal Government',
#  'Veteran politician becomes Nepal prime minister for 5th time',
#  'The Assassination of Jovenel Moïse',
#  'Texas man who waited 6 hours to cast ballot jailed for illegal voting',
#  "3 Lies And A Truth: What's Behind The GOP's Voting Rights Ploy",
#  'The Assassination of Jovenel Moïse',
#  'Texas man hailed as national hero arrested for illegal voting',
#  'Texas man who waited seven hours at polls is charged with voting illegally',
#  'Biden sends senior officials to Haiti amid power struggle and request for troops',
#  'On This Day: U.S. tests first atom bomb',
#  'Ukraine Reprised: Victoria Nuland Eyes Belarus In Talks With Ukrainian Official',
#  'Haiti is in peril, and there are no simple options, Opinions & Blogs News',
#  'Rahul unwilling, Sonia disinclined, will Kamal Nath assume a national role in Congress?',
#  'Ukraine Reprised: Victoria Nuland Discusses Belarus with Ukrainian Official',
#  "If U.S. continues to back Haiti's compromised politicians, nothing will improve after Moïse",
#  "Hervis Rogers May Spend Life in Prison Because of Trump's Big Lie",
#  'After its president was assassinated, Haiti needs international help more than\xa0ever',
#  'Commentary: Haiti before and after Moise',
#  'Op-Ed: Haiti before and after Moise',
#  'Weighing Haiti Intervention, U.S. Again Faces a Torturous Dilemma',
#  'In Haiti, Biden Faces an All Too Familiar Dilemma',
#  "Some Haitians turn to prayer after president's assassination",
#  'Status Update: 2 OC residents appointed judges; fundraiser for elderly adults is Wednesday',
#  "How to End Haiti's Terminal Despair",
#  'A Houston Man Is Arrested For Alleged Illegal Voting As Texas GOP Seeks Tighter Laws',
#  "Somalia Ex-Minister's Presidential Quest Tests Rigid Patriarchy",
#  "The Assassination of Haiti's President",
#  "Amanda Seyfried shares epic Mean Girls throwback and it's so fetch",
#  'Why the United States needs to intervene in Haiti — again',
#  'Corruption in Costa Rica: could the Cochinilla Case be a sign of progress?',
#  'Man who waited 6 hours to vote in 2020 primaries arrested, accused by Texas AG of voter fraud',
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  'Op-Ed: Haiti before and after Moise',
#  'Haitian arrested as alleged tie to assassination masterminds',
#  'Lil Wayne reveals if he really married Denise Bidot after cryptic tweet',
#  "Some Haitians turn to prayer after president's assassination",
#  "Some Haitians turn to prayer after president's assassination",
#  'A Houston Man Is Arrested For Alleged Illegal Voting As Texas GOP Seeks Tighter Laws',
#  'On This Day: South Sudan declares independence',
#  'Underfunded Polling Places Add to Voting Access Concerns',
#  'Man who waited 6 hours to vote in 2020 primary arrested, accused by Texas AG of voter fraud',
#  'The Battle Over State Voting Rights Is About the Future of Texas',
#  'Anti-PA rallies put Palestinian leaders on notice',
#  'U.S. Intervention in Haiti Would Be a Disaster—Again',
#  "Some Haitians turn to prayer after president's assassination",
#  'Haitian arrested as alleged tie to assassination masterminds',
#  'The Battle Over State Voting Rights Is About the Future of Texas',
#  'Haitian arrested as alleged tie to assassination masterminds',
#  'Texas man who famously waited hours to vote in Democratic primary faces up to 40yrs in prison for illegal voting',
#  'Haitian man arrested over alleged tie to assassination masterminds',
#  "Haitian arrested as alleged tie to masterminds behind president's assassination",
#  "‘Coalition of opposition parties possible to take on BJP'",
#  'Haitian arrested as alleged tie to assassination masterminds',
#  'Just How Rich Are Elon Musk, Donald Trump and These Other Big Names?',
#  'US Afghanistan withdrawal: Top commander steps down',
#  'US Afghanistan withdrawal: Top commander steps down',
#  "The Hit on Haiti's President",
#  'Haitian arrested as alleged tie to assassination masterminds',
#  'Taliban capture key Afghanistan-Iran border crossing',
#  'The assassination stirs a battle for control, in public and behind the scenes.',
#  "Police arrest Haitian with alleged tie to masterminds behind president's assassination",
#  'UK military not defeated in Afghanistan, says head of British armed forces',
#  'Haiti is divided over how to hold its next presidential election.',
#  'Man with Tampa Bay ties arrested in connection to Haiti assassination',
#  'Haitian arrested as alleged tie to assassination masterminds',
#  'Haitian Arrested As Alleged Tie To Assassination Masterminds',
#  'ஆஃப்கனில் இறுகும் தாலிபன் பிடி: இரான், துர்க்மெனிஸ்தான் எல்லைகளை கைப்பற்றினர்',
#  'Congressional Black Caucus chair ARRESTED by Capitol Police in protest photo-op over voting rights (VIDEO)',
#  "Don't hold your breath for Congress to pass the voting rights bill",
#  "California Supreme Court will be asked to grant extra time for state's redistricting panel",
#  "California Supreme Court will be asked to grant extra time for state's redistricting panel",
#  'Democrats face these major headwinds in 2022 elections',
#  'Rep. Courtney wants Google and Facebook to share more ad revenue with struggling local newspapers. Proposed legislation would force social media giants to renegotiate with papers.',
#  'Who is the real Geoff Diehl?',
#  'Democrats face these major headwinds in 2022 elections',
#  "Watch: Radical Fed Morphs From Central Bank To Bailout Kingpin... And Americans Aren't Paying Attention",
#  "Watch: Radical Fed Morphs From Central Bank To Bailout Kingpin… And Americans Aren't Paying Attention",
#  'California redistricting board must stop meeting privately to prove democracy still works',
#  "Ché Ahn Presents 'Leading With Conviction' an Event With Mike Pompeo to Promote Strength in Biblical Values Against All Odds",
#  'Republicans Attack Democrats on Rising Gas Prices',
#  "Ché Ahn Presents 'Leading With Conviction' an Event With Mike Pompeo to Promote Strength in Biblical Values Against All Odds",
#  'Capitol Recap: Georgia tax collections up $3.2 billion year over year',
#  'African Americans and the Economy under Trump',
#  'Republicans look to hammer Democrats over gas prices',
#  'A new inflation number, a new headache for Biden',
#  "It is time to revise the Federal Reserve's mission",
#  'Hillary Clinton, GOP leaders will join Biden for dinner with German chancellor',
#  'Fed Chair Powell Grilled by Grouchy Senators Over Inflation and Climate Change, Even as Economy Rebounds',
#  'Biden fires Social Security head, a Trump holdover who refused to resign',
#  'Virginia county to test power of GOP culture wars at ballot box',
#  "Washington's Insouciance on the Inflation Question Is Dangerous",
#  'Did Trump damage American democracy?',
#  'Why Democrats Should Fear Inflation',
#  "It's Not Too Late to Prosecute Trump-Era Crimes",
#  "America's Accountability Problem. Is Anyone Responsible Anymore?",
#  "America's Accountability Problem. Is Anyone Responsible Anymore?",
#  'A Michigan judge mulls sanctions for pro-Trump lawyers who argued to overturn the 2020 election.',
#  'Here are some of the specific provisions at the center of the fight over voting rights.',
#  'With unrest in Latin America, Biden must confront challenges to democracy close to home.',
#  "'The Rundown': Campaign cash makes the (political world) go 'round!",
#  'Ohioans accidentally paid jobless benefits can seek state waiver: Capitol Letter',
#  'On The Money: Inflation spike puts Biden on defensive',
#  "Bestselling Author Michael Wolff on his Trump Exposés: 'There Was No Plan. He Is Deranged'",
#  "Attempt to seize Post reporters' email data came a day before Barr left office.",
#  'In a milestone, Schumer will propose federal marijuana legalization.',
#  'Top Democrats agree to a $3.5 trillion budget to advance alongside the bipartisan infrastructure deal.',
#  'The Energy Department aims for cheaper batteries to make clean energy more viable.',
#  'The injustice of stereotyping Malaysia as a failed state',
#  'Social Security Cost-of-Living Adjustment Looks Uncertain',
#  'Merkel versus mania',
#  "POLITICO Playbook PM: What is (and isn't) in the Dems' ‘go-big' bill",
#  'Eiffel Tower reopens in Paris after longest closure since WWII',
#  "Surgeon General Murthy says COVID-19 misinformation an 'urgent' health threat",
#  'Washington Monument reopens to public for first time in 6 months',
#  'Emmanuel Macron mandates COVID-19 vaccines for French health workers',
#  'At least 41 dead in fire at Iraqi hospital treating COVID-19 patients',
#  'How Tucker Carlson became the voice of white grievance',
#  'Court Reform Commissions, Past and Present',
#  'Fidelis Mhonda',
#  'Trump Easily Wins CPAC Straw Poll, Again Insinuates Stolen Election in Speech',
#  'CNN Programs',
#  'Iowa voting rights activist considers run for Iowa governor',
#  'Iowa voting rights activist considers run for Iowa governor',
#  'Iowa voting rights activist considers run for Iowa governor',
#  'Iowa voting rights activist considers run for Iowa governor',
#  'Liberia: No Money for Biometric Voter Registration',
#  'Iowa voting rights activist considers run for Iowa governor',
#  'DeJear, possible Iowa governor candidate, will visit Clinton today',
#  'DeJear, possible Iowa governor candidate, will visit Clinton Tuesday',
#  'Fact-checking Joe Biden on voter turnout in 2020',
#  "Kenya: Let Integrity of Polls Come Before IEBC's Fixation With Huge Budget",
#  'Trump Easily Wins CPAC Straw Poll, Again Insinuates Stolen Election in Speech',
#  'Biden assails GOP state voting laws in fiery speech',
#  'Mitt Romney sells $23.5M home after years of backlash from neighbors',
#  'Mitt Romney sells $23.5M home after years of backlash from neighbors',
#  "John McCain adviser explains why the Trumpified GOP has become ‘the greatest threat since 9/11'",
#  "Bogus Claims From the Poor People's Campaign",
#  "U.S. bishop takes rare step, removes priest who said 'anyone who supports Democrats will burn in hell'",
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  'Biden to tap LA Mayor Eric Garcetti as US ambassador to India, White House says',
#  'Three Percenters are known for terrorist plots, attacks: ADL',
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  "VA Governor's Debate Canceled After GOP Candidate Rejects Rules",
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  'Biden nominates L.A. Mayor Eric Garcetti as U.S. ambassador to India',
#  'Biden nominates LA Mayor Eric Garcetti as US ambassador to India',
#  'German Chancellor Angela Merkel to receive Johns Hopkins honorary degree',
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  "'We Need Assistance': Haiti's Interim Leader Pleads For U.S. Troops",
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  "Haiti's Interim Leader Requests U.S. Troops",
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  "'We need help': Haiti's interim leader requests US troops",
#  "‘We need help': Haiti's interim leader requests US troops",
#  "'We need help': Haiti's interim leader requests U.S. troops",
#  "'We need help': Haiti's interim leader requests US troops",
#  "'We need help': Haiti's interim leader requests US troops",
#  "'We need help': Haiti's interim leader requests U.S. troops",
#  "'We need help': Haiti's interim leader requests US troops",
#  "'We need help': Haiti's interim leader requests US troops",
#  "‘We need help': Haiti's interim leader requests US troops",
#  "'We need help': Haiti's interim leader requests US troops",
#  "'We Need Help': Haiti's Interim Leader Requests US Troops",
#  "‘We need help': Haiti's interim leader requests US troops",
#  "'We need help': Haiti's interim leader requests US troops",
#  "'We need help': Haiti's interim leader requests US troops",
#  "'Friendly' Wiretaps, Neck Rubs and Handshakes: History of Merkel's Encounters With US Presidents",
#  "Haiti requests US to deploy troops after the President's assassination",
#  "'We need help': Haiti's interim leader requests US troops",
#  "'We need help': Haiti's interim leader requests U.S. troops",
#  "Haiti's interim leader requests U.S. military support to help stabilize country",
#  'Mitt Romney sells his oceanfront La Jolla mansion for $23.5 million',
#  "US Reflects on End of Its ‘Forever War'",
#  'US Reflects on End of Its Forever War',
#  "'We need help': Haiti's interim leader requests US troops",
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  'Wisconsin Bishop Takes Rare Step Of Removing Priest Over Political Comments',
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  "We need help': Haiti's interim leader requests U.S. troops",
#  'This day in history, July 13, 2021',
#  "Haiti's Interim Leader Is Asking For U.S. Troops To Help With Security",
#  "‘We need help': Haiti's interim leader requests US troops",
#  'Wisconsin bishop takes rare step of removing defiant priest',
#  "James Altman, priest who said Catholics can't be Democrats, removed from posting by bishop",
#  "‘We need help': Haiti's interim leader requests US troops",
#  "When Erdogan's Turkish economic miracle began failing",
#  "Trump says Joint Chiefs Chairman Mark Milley is the 'last person' with whom he would attempt a coup",
#  "‘We need help': Haiti's interim government requests US troops as it tries to stabilize country after president's assassination",
#  "Analysis-When Erdogan's Turkish economic miracle began failing",
#  "‘We need help': Haiti's interim leader requests U.S. troops",
#  "Analysis-When Erdogan's Turkish economic miracle began failing",
#  "Wisconsin bishop removes pastor who said Catholics can't be Democrats",
#  'Mitt Romney sells his oceanfront La Jolla mansion for $23.5M',
#  'Wikipedia Co-Founder Reveals Why Online Encyclopaedia Cannot Be Trusted',
#  "10 Things in Politics: Biden's Big Tech-busting team",
#  "Analysis-When Erdogan's Turkish economic miracle began failing",
#  "'All of a sudden, people discovered Idaho' — and flooded a scenic mountain town in droves",
#  "‘We need help': Haiti's interim leader requests US troops",
#  'House Republicans take the lead in money chase for midterms',
#  'Officials explain how growth of state will affect redistricting',
#  "U.S. aid chief seeks more effective help for Haiti amid 'chaos'",
#  'Murkowski Outraised Trump-Backed Challenger in Second Quarter',
#  "U.S. aid chief seeks more effective help for Haiti amid 'chaos'",
#  'Former Supreme Court justice, retired judge are choices for redistricting tie-breaker',
#  "U.S. aid chief seeks more effective help for Haiti amid 'chaos'",
#  "U.S. aid chief seeks more effective help for Haiti amid 'chaos'",
#  'Democrats, heed the warnings: 18 months to a Republican Congress — unless you fight',
#  "Halfway through 2021, 5 senators mum on if they're running for reelection in 2022",
#  'Democrats have to end gerrymandered districts — eventually',
#  "Biden's midterm strategies start to come into focus",
#  'Lawmakers Urged To Create Opportunities For Candidates Of Color',
#  'Cottle: The nation needs a reality-based GOP',
#  'Democrat Infighting Ensues over $2.4 Trillion Tax Increases',
#  "What helps Haiti? ‘Working with' versus ‘doing for.'",
#  'Paul LePage Is Running for Governor of Maine Again',
#  'Why are former presidents running for lower-level posts?',
#  "In wake of president's assassination, Ayanna Pressley calls for deportation moratorium for Haitians",
#  "Morning Digest: Hawaii is hosting its first open governor's race in years. Here's the field so far",
#  'Haiti requests US security forces to guard infrastructure amid turmoil',
#  "California turned its back on the GOP. Four Harvard degrees won't help Republican Lanhee Chen",
#  'Grand Traverse County redistricting gets underway',
#  'Will growing primary opposition hurt or help Gov. Abbott?',
#  "Biden falls back on old Democrat sales pitch: Big spending is 'for the children'",
#  "Pacquiao vs Duterte for president: A title bout the Philippines can't stop watching, Asia News",
#  'Op-ed: US efforts have shown that we need better foreign aid — not more of it',
#  "Beijing bucks keep Democrats mum on China's abuses",
#  'Commentary: US efforts have shown that we need better foreign aid — not more of it',
#  'Commentary: US efforts have shown that we need better foreign aid — not more of it',
#  'The key lesson we must learn from our experience in Afghanistan',
#  "KINZINGER's BIG HAUL — LATINO CAUCUS' MAP MOVES — COOK COUNTY STRIKE SCOOP",
#  "Texas Dems Are Fighting for Democracy—Why Won't Washington's?",
#  "Texas Dems Are Fighting for Democracy—Why Won't Washington's?",
#  "How the GOP's Long War on the IRS Threatens the Infrastructure Deal",
#  'Republican screwups on infrastructure hurt people from Kentucky to Michigan to Mississippi to NYC',
#  'Nikki Haley endorses Ciattarelli',
#  'Bipartisan infrastructure negotiators scramble for deal as key funding option dropped',
#  'Bipartisan infrastructure negotiators scramble under deadline',
#  "GARCETTI to INDIA — JENNER doesn't want TRUMP nod — GAINES gets in — HEAT WAVE threatens power grid",
#  'In hour-long call, Biden discusses ransomware with Putin after another massive attack',
#  'Moderates and progressives suss out budget deal',
#  'POLITICO Playbook PM: Schumer plays hardball — and Breyer talks',
#  "In the Philippines, it's legal to have sex with a 12-year-old. Activists are trying to change that",
#  'Brewing battle over tax hikes to test Democratic unity',
#  "Biden's cautious Cuba stance may haunt Florida Dems",
#  'Surprising levels of inflation are increasingly being driven by wages, not goods',
#  'Transcript: All In with Chris Hayes, 7/8/21',
#  'Progressive challenger hopes to catch Congressman with his pants down…\xa0again',
#  "SC's Tim Scott pulls in $9.6M from donors, setting aside millions before 2022 race",
#  "Missouri AG Schmitt spotlights 'pushback' against Biden in 2022 Senate GOP primary",
#  "Biden's gun control-backing ATF pick wins support from Pennsylvania Democrat eyeing Senate run",
#  'Biden selects Jeff Flake for Turkey ambassadorship',
#  "John Cornyn calls Dick Durbin's DACA bluff",
#  "Biden's gun control-backing ATF pick wins support from Pennsylvania Democrat eyeing Senate run",
#  'Biden selects Jeff Flake for Turkey ambassadorship',
#  "Biden's gun control-backing ATF pick wins support from Pennsylvania Democrat eyeing Senate run",
#  "Speculation builds over Matthew McConaughey's political future as he mulls bid for governor of Texas",
#  'Pressureis on toredrawmap of Idaho districts',
#  'Biden nominates first out lesbian to ambassador-level post',
#  "Plugging Obamacare's biggest hole poses dilemma for Democrats",
#  "Morning Digest: Top GOP recruit is back after narrow loss—and this time, he's embracing his party",
#  'Key administration posts remain vacant 6 months into Biden presidency',
#  "AOC says progressives will 'tank' infrastructure bill without bold climate change provisions",
#  "NJ-10 Activist Takes On Donald Payne, 'Establishment Democrats'",
#  'As Republicans Take Aim at Voting, Democrats Search for a Response',
#  'Biden names Arizona Republican Jeff Flake as his ambassador pick for Turkey',
#  "California's immigrant crackdown propelled Latinos to Washington. After Trump, could it happen again?",
#  'Biden names Arizona Republican Jeff Flake as his ambassador pick for Turkey',
#  'Biden names Arizona Republican Jeff Flake as his ambassador pick for Turkey',
#  "Iran rebels see Tehran's new hardline president as a chance to bring down the regime",
#  "California's immigrant crackdown propelled Latinos to Washington. After Trump, could it happen again?",
#  'Democrats Set Political Tripwire for 2024: Payments to Parents',
#  'Murphy blasts Ciattarelli comments on LGBTQ school curriculum. How will it play in November?',
#  'Florida progressives have growing power, but where are their candidates?',
#  'Florida progressives have growing power, but where are their candidates?',
#  'Democrats Set Political Tripwire for 2024: Payments to Parents',
#  "Pelosi Husband's Tech Stock Spotlights Law on Lawmaker Trades",
#  'Political crisis in Haiti deepens over rival claims to power, World News',
#  'What the book An Ugly Truth reveals about Facebook and Russian interference',
#  'What the book An Ugly Truth reveals about Facebook and Russian interference',
#  'What a new book reveals about Facebook and Russian interference',
#  "Auchincloss's PRIMARY PROTECTION — GRADING Walsh and Janey — Lawmakers flex MUSCLE over Baker",
#  'Top House Intel staffer, former Schiff chief departs for K Street',
#  "Openly gay leaders say Michigan is at a ‘turning point' for LGBTQ acceptance as fight for rights heats up",
#  "It's legal to have sex with a 12-year-old in the Philippines. Activists are trying to change that",
#  'Under Philippine law, 12-year-olds can consent to sex. Activists are trying to change that',
#  "POLITICO Playbook: Biden's choice: The filibuster or voting rights?",
#  "Romney 'felt a pit in his stomach' at 'surprisingly good' early Trump election night numbers, book says",
#  "Romney 'felt a pit in his stomach' at 'surprisingly good' early Trump election night numbers, book says",
#  'Campaign 2012',
#  "Romney 'felt a pit in his stomach' at 'surprisingly good' early Trump election night numbers, book says",
#  'Orono woman denies voting twice in November election',
#  "Mexico Presidential Succession Heats Up Early With Ebrard's Bid",
#  'Arizona Woman Charged With Voter Fraud in 2020 Presidential Election',
#  'Caitlyn Jenner Has a Film Crew Chronicling Gubernatorial Campaign',
#  "Biden's rhetoric on voting laws is unhinged",
#  "Haiti president's widow says domestic opponents plotted assassination",
#  'Ayatollah Seyyed Ali Khamenei Fast Facts',
#  'Anies, Ganjar, or Prabowo? What kind of politics and leaders do young Indonesians want for the 2024\xa0elections?',
#  'On This Day: Bugs Bunny voice Mel Blanc dies',
#  'An anti-corruption party triumphs in Moldova',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Electoral clash looms between LDP bigwigs in Yamaguchi',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Iran anger at US, European support for opposition group',
#  'Iran expresses anger at U.S., European support for opposition group',
#  'Iran anger at US, European support for opposition group',
#  'Iran anger at US, European support for opposition group',
#  'Iran anger at US, European support for opposition group',
#  'Iran anger at US, European support for opposition group',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Iran anger at US, European support for opposition group',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Iran anger at US, European support for opposition group',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'Gantz said to weigh tapping Amir Peretz as IAI board chair',
#  'IMF: How social unrest can inspire changes in policy',
#  'Iran anger at US, European support for opposition group',
#  'Democrats see an opportunity in Cuban protests',
#  'Iran anger at US, European support for opposition group',
#  'Iran anger at US, European support for opposition group',
#  'Iran anger at US, European support for opposition group',
#  'How the US lost the plot in Afghanistan',
#  'Youngkin declines debate in part over moderator Woodruff',
#  'On This Day: Skylab falls to earth',
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  'Galina Kulikova: A People-to-People Diplomat for China-Russia Relations',
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "‘We don't like bullies, egomaniacs or jerks': Allen West crashes Texas governor's race",
#  'Iran anger at US, European support for opposition group',
#  "White House Announces Biden's Picks for Ambassadors to Chile, Bangladesh, India and France",
#  "Blake Masters enters GOP Senate race, saying age, political experience ‘overrated'",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  'Democrats see an opportunity in Cuban protests',
#  "Blake Masters enters GOP Senate race, saying age, political experience 'overrated'",
#  'Iran fumes over American, European support for opposition group at Berlin rally',
#  'PDP-Laban: From fighting dictatorship to fighting each other',
#  'Part 1: Sentimental Analysis Using BERT',
#  "‘We don't like bullies, egomaniacs or jerks': Allen West crashes Texas governor's race",
#  'Jan. 6 rioters face years in jail for ransacking Capitol. Harsher penalties loom for more violent defendants',
#  'Frankly, We Did Win This Election review: a devastating dispatch from Trumpworld',
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "Will Euro 2020 change England for ever? I've heard it all before",
#  'McCarthy, GOP face a delicate dance on Jan. 6 committee',
#  'Frankly, We Did Win This Election review: a devastating dispatch from Trumpworld',
#  'Tanzania: Why Tanzania Will Be Left Behind Without New Constitution',
#  "EXPLAINER: Who's who in the probe of Haiti's assassination",
#  "Latino Americans are optimistic about the country's future despite being hit hard by the pandemic, a Pew survey finds",
#  'Moldova election: Pro-EU party leads in early results',
#  'President Biden Announces His Intent to Nominate Four Individuals to Serve as Ambassadors',
#  "New Book Remembers FDR's Friendship with Distant Cousin and Rumored Love Daisy Suckley: 'A Constant Presence'",
#  'Moldova election: Pro-EU party headed to victory  DW',
#  "People are ‘swimming' in New York subway stations after Elsa. What's the climate crisis got to do with it?",
#  'The world looks on in disbelief as America abandons Afghanistan',
#  "John Ratcliffe's Zombie Campaign Paid His Wife $3,000 A Month To Manage Its Books",
#  'Factbox: Eight quotes by and about former Louisiana Gov. Edwin Edwards',
#  'Eight quotes by and about former Louisiana Gov. Edwin Edwards',
#  'FACTBOX-Eight quotes by and about former Louisiana Gov. Edwin Edwards',
#  'Factbox: Eight quotes by and about former Louisiana Gov. Edwin Edwards',
#  'Republicans Outraise Democrats in Second Quarter ahead of 2022 Midterms',
#  'Factbox: Eight quotes by and about former Louisiana Gov. Edwin Edwards',
#  'Samuel Gregg',
#  'How important are women candidates for the Democratic Party, exactly?',
#  "‘Breonna's Law' author Attica Scott is running for US Congress",
#  "Late census numbers compress redistricting panel's schedule",
#  "Late census numbers compress redistricting panel's schedule",
#  "Late census numbers compress redistricting panel's schedule",
#  'Factbox: Eight quotes by and about former Louisiana Gov. Edwin Edwards',
#  "Late census numbers compress redistricting panel's schedule",
#  "Late census numbers compress redistricting panel's schedule",
#  'Edwin W. Edwards, Flamboyant Louisiana Governor Later Imprisoned For Fraud And Extortion, Dies At 93',
#  'Leaked documents appear to confirm a Russian plot to support Trump in 2016, Guardian report says',
#  "Late census numbers compress redistricting panel's schedule",
#  'Edwin Edwards, former Louisiana governor, dies dies at 93',
#  'Prince William supervisor Lawson joins GOP race to unseat Jennifer Wexton',
#  'Former Louisiana Gov. Edwin Edwards dies at 93',
#  'Flamboyant former Louisiana Gov. Edwin Edwards dies at 93',
#  'Leaked documents appear to confirm a Russian plot to support Trump in 2016, Guardian report says',
#  'Leaked documents appear to confirm a Russian plot to support Trump in 2016, Guardian report says',
#  'Leaked documents appear to confirm a Russian plot to support Trump in 2016, Guardian report says',
#  'Former Louisiana Gov. Edwin Edwards dies at 93 :: WRAL.com',
#  'Democrats Take Aim at the 2001 Authorization for Use of Military Force',
#  'Reuters journalist killed covering clash between Afghan forces, Taliban',
#  'Warnock raises $7.2M in quest to keep Senate seat in 2022',
#  'Warnock raises $7.2M in quest to keep Senate seat in 2022',
#  'Warnock raises $7.2M in quest to keep Senate seat in 2022',
#  'Warnock raises $7.2M in quest to keep Senate seat in 2022',
#  'Warnock raises $7.2M in quest to keep Senate seat in 2022',
#  'Warnock raises $7.2M in quest to keep Senate seat in 2022',
#  'Edwin Edwards, roguish Louisiana governor, dies at 93',
#  'Michigan GOP plots shift in statewide nomination process amid fight over future',
#  'Cross-Practice Duo Combine Forces and Join McDermott to Deliver Enhanced Collaborative Client Service Approach',
#  'Edwin Edwards, roguish Louisiana governor, dies at 93',
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  'Astroturf: AP Amnesty Story Mostly Quotes Paid Zuckerberg Shills',
#  "Amnesty: Zuckerberg's Astroturf Empire Occupies the Associated Press",
#  'Astroturf: AP Amnesty Story Mostly Quotes Paid Zuckerberg Shills',
#  "In Aftermath Of Baazov's Acquittal For Insider Trading, Has Online Poker Grown Too Big To Regulate?",
#  "The Republicans' Latest Skeezy Campaign Trick: Cash Swaps to Help Each Other",
#  'Democrats Turned San Francisco Into Gotham City',
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  'Demi Lovato posts intimate snap of herself soaking in the bathtub',
#  "The man behind Biden's push to promote business competition",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  'California prison riot leaves at least 30 inmates injured',
#  "Populist Edwin Edwards, a ‘Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
#  "Ticket sales are moving slowly for the coming Trump-O'Reilly stadium tour",
#  "Populist Edwin Edwards, a 'Cajun King,' loved his Louisiana",
# ...
#  "Brazil's Bolsonaro recovers in hospital, no surgery planned",
#  "Brazil's Bolsonaro recovers in hospital, no surgery planned",
#  'Janesville businesswoman launches congressional campaign',
#  'Janesville businesswoman launches congressional campaign',
#  "Brazil's Bolsonaro recovers in hospital, no surgery planned",
#  'Trump denies coup attempt in latest attack on Milley',
#  "Pa. House GOP commits to public meetings, vows ‘most transparent' congressional redistricting process ever",
#  "‘Carpetbagger Katie!': Protest Turns Violent At Democrat's Town Hall, Several Get Into Scuffle",
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  'Democratic group pledges $10 million in ads to support Biden agenda, as outside support grows',
#  'Jair Bolsonaro clouds 2022 vote with fraud claims',
#  "‘Easier To Cheat, Harder To Prove': Former Top DHS Official Testifies On Election Reforms",
#  'Joint committee on redistricting sets public hearing dates',
#  'Democrats must win big on health care to have a shot in the midterms',
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  "Brazil's Far-Right President Admitted To Hospital… For Hiccups",
#  "Brazil's Bolsonaro recovering in hospital and unlikely to need surgery, says son",
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  'Former Georgia ethics official to challenge McBath',
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  'Former GOP Hill aide pleads guilty in child porn case',
#  "Capitol Recap: It's time to check checks as Georgia fundraising reports roll in",
#  "Brazil's Bolsonaro may need intestinal surgery to relieve chronic hiccups",
#  'With NYC primary, preliminary results (ahem) are in on ranked-choice voting',
#  'Brazilian leader evaluated for possible emergency surgery',
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  'Cunningham announcing plan to legalize marijuana in SC',
#  'After bad hiccups, Bolsonaro may need intestinal surgery',
#  'Brazilian leader evaluated for possible emergency surgery',
#  'Brazilian leader evaluated for possible emergency surgery',
#  "Brazilian President Jair Bolsonaro may need emergency surgery after hiccupping '24 hours a day' for nearly a week",
#  "Why redrawing Utah's political maps will be a sprint to the finish this year",
#  'Jill Biden will attend Opening Ceremonies at Olympics',
#  'Morning Digest: Progressives gained unprecedented clout in New Mexico legislature via key 2020 wins',
#  'Brazil President Jair Bolsonaro in hospital after battling hiccups for 10 days',
#  'Eric Adams Shows Yet Again That Progressives Dominate The Dialogue, Only To Lose Elections',
#  'Cunningham would legalize marijuana if elected SC governor',
#  "Bad hiccups, but no immediate surgery for Brazil's president",
#  "Bad hiccups, but no immediate surgery for Brazil's President",
#  "Bakersfield native Angel Lara announces bid for David Valadao's seat in Congress",
#  "Lake County's congressional reps ask EPA to tighten regulation of EtO emissions",
#  "Brazil's Bolsonaro recovers in hospital, no surgery planned",
#  "Scuffle breaks out at Rep. Katie Porter's town hall",
#  "Brazil's Bolsonaro recovers in hospital, no surgery planned",
#  "Brazil's Bolsonaro recovers in hospital, no surgery planned",
#  'Fight breaks out at Katie Porter town hall',
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  "Brazil's Bolsonaro recovers in hospital, no surgery planned",
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  "Brazil's Bolsonaro recovers in hospital, no surgery planned",
#  'Brazilian leader admitted to hospital for persistent hiccups',
#  "Here's why ranked choice voting is different for Democrats",
#  "Climatologist says recent rain doesn't spell the end of drought for northeastern Illinois",
#  "Biden says democracy threatened by Republican ‘election subversion'",
#  "US democracy threatened by 'election subversion', says Biden",
#  "Biden says US democracy threatened by Republican 'subversion'",
#  "Democrats are finally paying attention to Trump's Arizona audit: House opens probe into Cyber Ninjas",
#  "Biden says US democracy threatened by Republican 'subversion'",
#  "2nd delay in GOP Congress candidate's murder plot case",
#  'Great, QAnon Candidates Are Trying to Take Over Congress',
#  "Biden Calls Republican State Election Law Changes 'Assault on Liberty'",
#  'House Republicans Shatter Fundraising Record With $45M Haul',
#  "2nd delay in GOP Congress candidate's murder plot case",
#  "2nd delay in GOP Congress candidate's murder plot case",
#  "2nd delay in GOP Congress candidate's murder plot case",
#  "2nd delay in GOP Congress candidate's murder plot case",
#  "2nd delay in GOP Congress candidate's murder plot case",
#  "2nd delay in GOP Congress candidate's murder plot case",
#  "2nd delay in GOP Congress candidate's murder plot case",
#  'In visit to Philadelphia, Joe Biden pushing for stalled voting rights law',
#  "2nd delay in GOP Congress candidate's murder plot case",
#  "2nd delay in GOP Congress candidate's murder plot case",
#  'GOP congressional candidate used campaign cash to attend Trump D.C. rally, Democrats allege in FEC complaint',
#  "2nd delay in GOP Congress candidate's murder plot case",
#  'Omaha state lawmaker to run for Nebraska House seat in 2022',
#  'Omaha state lawmaker to run for Nebraska House seat in 2022',
#  'Omaha state lawmaker to run for Nebraska House seat in 2022',
#  'Omaha state lawmaker to run for Nebraska House seat in 2022',
#  'Omaha state lawmaker to run for Nebraska House seat in 2022',
#  'Democratic primary in Ohio emerges as test for...',
#  'Minnesota congressional candidates start money race early',
#  'Corporate PACs resume donations to McCarthy after brief pause',
#  'In visit to Philadelphia, Biden pushing for stalled voting rights law',
#  'Democratic primary in Ohio emerges as test for progressives',
#  'In visit to Philadelphia, Biden pushing for stalled voting rights law',
#  'Kara Hahn Raises Over $250,000, So Far, In Congressional Run: Rep',
#  'In visit to Philadelphia, Biden pushing for stalled voting rights law',
#  'In visit to Philadelphia, Biden pushing for stalled voting rights law',
#  'In visit to Philadelphia, Biden pushing for stalled voting rights law',
#  "'Landslide': Michael Wolff on Trump's Final Days in Office & Why He Still Rules the Republican Party",
#  'Omaha state lawmaker to run for Nebraska House seat in 2022',
#  "Biden says US democracy threatened by Republican ‘subversion'",
#  'List of companies that have resumed donations to GOP election objectors',
#  'Biden Campaign Spokesman Joins U.S. Trade Representative as a Top Communications Officer',
#  'NRCC boasts record, $45.4 million haul in second quarter, outpaces DCCC',
#  'Stacey Abrams was just nominated for an Emmy Award. Really',
#  'Stacey Abrams was just nominated for an Emmy Award. Really',
#  'House Republicans Blow Away Democrat Counterparts in Record-Shattering Fundraising Quarter',
#  'House Republicans Blow Away Dems in Record-Shattering Quarter',
#  'In voting rights debate, a struggle to preserve American democracy',
#  "NYC hobbles Democrats' narrative on state voting reforms",
#  'After maverick stances, Jeff Brandes loses Senate Judiciary Committee post in Tallahassee',
#  'Targeting Dark Money Attacking Democracy, Watchdog Files FEC Complaint Against 23 Super PACs',
#  'NRCC boasts record, $45.4 million haul in second quarter, outpaces DCCC',
#  "Friday's Campaign Round-Up, 7.16.21",
#  "Biden steps up fight for voting rights: 'The big lie is just that -- a big lie!'",
#  'Dem Star Nina Turner Blows Pledge Not to Take Lobbyist Money',
#  'Watchdog files FEC complaint against super PACs linked to congressional leaders',
#  "The Trump DOJ tried to seize 3 Washington Post journalists' communications the day before Attorney General William Barr stepped down, new documents show",
#  'Campaigning heats up as off-election year sees surge in ad spending',
#  "Baker 'not surprised' by infighting in Massachusetts GOP",
#  "Baker 'not surprised' by infighting in Massachusetts GOP",
#  "Baker 'not surprised' by infighting in Massachusetts GOP",
#  "Baker 'not surprised' by infighting in Massachusetts GOP",
#  'Voting rights: How the battle is unfolding across the US',
#  'Fitzpatrick Sets Record-Breaking Fundraising Quarter: Report',
#  'Voting rights: How the battle is unfolding across the US',
#  'The new playbook for partisan gerrymandering',
#  'Marjorie Taylor Greene chides QAnon over Trump August claim: "Careful who you believe"',
#  "President Biden blasts ‘un-American' voting limits",
#  "Biden blasts ‘un-American' voting limits as Texas Dems take dramatic action",
#  'U.S. House select committee announces first hearing to probe Jan. 6 attack',
#  'House Republicans post record fundraising ahead of 2022 race',
#  'House Republicans post record fundraising ahead of 2022 race',
#  'House Republicans Post Record Fundraising Ahead of 2022 Race',
#  "Baker 'not surprised' by infighting in Massachusetts GOP",
#  "Biden blasts GOP voting restrictions push: 'The big lie is just that -- a big lie!'",
#  "Baker 'not surprised' by infighting in Massachusetts GOP",
#  'Fundraiser draws supporters, protesters',
#  'Don Jr. Mocks Black Women Protesting For Their Right to Vote',
#  'House Republicans post record fundraising ahead of 2022 race',
#  'House Republicans Post Record Fundraising Ahead Of 2022 Race',
#  'House Republicans post record fundraising ahead of 2022 race',
#  'Biden to make speech on voting rights in Philadelphia',
#  'Biden to make speech on voting rights in Philadelphia',
#  'Biden to make speech on voting rights in Philadelphia',
#  'Biden to make speech on voting rights in Philadelphia',
#  'Disgraced former Florida deputy gets 12-year prison sentence for planting drugs',
#  'Arizona state Senator calls for new election, says Biden electors must be recalled',
#  'Trump Releases Letter From Ex-US Attorney Alleging Barr Pressured Him Not to Probe Voter Fraud Claims',
#  'Fox News aired a legal disclaimer when Trump started airing 2020 election conspiracy theories in his CPAC speech',
#  'Biden to make speech on voting rights in Philadelphia',
#  'Trump Releases Letter From Ex-US Attorney Alleging Barr Pressured Him Not To Probe Voter Fraud Claims',
#  'Officials change animal names over discrimination concerns',
#  'Wife of former Washington QB Dwayne Haskins charged with domestic battery after knocking out one of his teeth',
#  "‘It's completely unAmerican': Trump faults Big Tech for meddling in the 2020 presidential election",
#  'Kanye West write-in vote among ballots initially counted twice in Georgia',
#  "County won't offer up voting machines to election audit",
#  "Arizona's Maricopa County approves $3M for new vote-counting machines",
#  "Tioga County won't offer up voting machines to election audit",
#  'Alan Dershowitz says evidence suggests 2020 election "wasn\'t stolen" from Trump',
#  'Fox News aired a legal disclaimer when Trump started airing 2020 election conspiracy theories in his CPAC speech',
#  'Michigan investigating individuals making election fraud claims to gain money, publicity',
#  "Ukraine to sanction top Belarus security officials, Lukashenko's son",
#  "Ukraine to sanction top Belarus security officials, Lukashenko's son",
#  "Ukraine to sanction top Belarus security officials, Lukashenko's son",
#  "Ukraine to sanction top Belarus security officials, Lukashenko's son",
#  "Pennsylvania County Won't Offer Up Voting Machines To Sen. Doug Mastriano's Election Audit",
#  "Trump's Former Defence Secretary Rooted for Biden on Election Night, New Book Claims",
#  "Ukraine to sanction top Belarus security officials, Lukashenko's son",
#  "Ukraine to Sanction Top Belarus Security Officials, Lukashenko's Son",
#  "WATCH: Biographer Michael Bender reveals Trump's top priority",
#  "Trump Responds to Biden's Criticism of Those Who Doubt Integrity of 2020 Election",
#  "Bizarre seven-point plan to reinstate Trump in ‘days, not years' distributed at CPAC",
#  "Biden: 'peddlers of lies' are threatening American democracy – video",
#  "Arizona Senate President Says 2020 Election Audit's Ballot Count Doesn't Match Maricopa Tally",
#  "New FEC filings show Giants owner is ignoring January 'pledge'",
#  'Brazilian TV presenter declares himself presidential hopeful on air – Asean News',
#  "Arizona Senate President Says 2020 Election Audit's Ballot Count Doesn't Match Maricopa Tally",
#  'Stop talking about November 2020 election',
#  'Michigan judge blasts "fantastical" election fraud claims',
#  "Arizona Senate President Says 2020 Election Audit's Ballot Count Doesn't Match Maricopa Tally",
#  "Opinion : Maria Bartiromo's top 10 fails",
#  "Trump Hails Allegations of 'Provable Fraud' in Georgia 2020 Election Count",
#  'Ex-Trump official says GOP greater national security threat to U.S. than ISIS, Al Qaeda',
#  'Social media post falsely states that Pennsylvania has started a full audit for the 2020 election',
#  'The last American election? 2020 and the rise of the anti-democrats',
#  "‘These are hardworking Americans who have children and need those resources': Secy. Wally Adeyemo on child tax credit",
#  'Former AG Barr Denies Giving Orders Not to Probe Election Fraud Claims',
#  'Sen. Durbin: Inexcusable that this wealthy country has children struggling for basics',
#  'National Urban League releases its State of Black America 2021 report',
#  "Congress raises stakes with examination of Arizona's sham 'audit'",
#  'Toyota Ends Donations to Targeted Republican Lawmakers After Lincoln Project Ad',
#  'Macron to revive controversial pension overhaul once Covid is under control',
#  "An indictment of William Barr's tenure as attorney general",
#  'Michigan asks for $11K in legal fees for defending state in Donald Trump election suit',
#  "Don Trump Jr. says he'll be 'very involved' in 2022 midterm campaigns",
#  'House Committee Launches Probe Into Arizona Election Audit',
#  "'They wanted to undermine faith in our democracy': pro-Trump lawyers called out in court",
#  'Julian Castro Joins NBC News And MSNBC As Political Analyst',
#  "That was fleeting: Twitter kills off ephemeral 'fleets'",
#  "Don Trump Jr. says he'll be 'very involved' in 2022 midterm campaigns",
#  "Bizarre seven-point plan to reinstate Trump in ‘days, not years' distributed at CPAC",
#  '2 charged with plotting to blow up Democratic headquarters',
#  "Mike Pompeo Reportedly Said 'Crazies Have Taken Over' as Donald Trump, Allies Decried Vote Fraud",
#  'Michigan AG to probe people making money off election claims',
#  "Michigan, Arizona Move To Investigate Trump And GOP's Election Interference Efforts Amid Republican Audit Push",
#  'Trump Releases Letter From Former US Attorney Blasting DOJ Orders on Handling Election Fraud Claims',
#  'Michigan AG to probe people making money off election claims',
#  'Trump was desperate to beat Joe Biden and said on Election Day that \'I can\'t lose to this f------ guy," new book says',
#  "Once rivals, Biden and Sanders are now partners in power. Here's how it happened.",
#  "Trump praises Jan. 6 rioters as ‘patriots' and ‘peaceful people'",
#  'Toyota halts donations to Republicans who opposed election certification',
#  "Election audit plan a ‘disgrace to democracy,' governor says",
#  '3 Reasons to Put Retirement Savings Into Your IRA Before Your 401(k)',
#  '3 reasons why you should prioritize putting money in your IRA over your 401(k)',
#  'Things to consider before setting up a 401(k) plan for your employees',
#  '401(k) participants flourished in 2020 with a soaring stock market',
#  'What Is a 403(b)?',
#  'Your Guide to Retirement Planning',
#  "Many 401(k) investors don't use target-date funds the right way",
#  '4 Simple Moves to Shift Your Retirement Savings Into Overdrive',
#  '4 Unexpected Ways to Level Up Your 401(k)',
#  'Should you put cryptocurrency in your retirement account?',
#  ...]
